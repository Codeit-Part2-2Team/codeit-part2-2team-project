# %% [markdown]
# # exp_20260503_efficientnet_b2 실험
#
# **목적**: baseline Stage 1 가중치를 재사용하고, HPO trial_0008 결과(efficientnet_b2)로 Stage 2를 학습·평가합니다.
#
# | 항목 | 값 |
# |------|----||
# | Stage 1 | `exp_20260420_baseline_yolo26n` 가중치 재사용 |
# | Stage 2 모델 | efficientnet_b2 |
# | HPO trial | trial_0008 (Top-1 Acc 0.9041) |
# | lr0 | 0.000645 |
# | lrf | 0.09057 |
# | weight_decay | 0.01013 |
# | label_smoothing | 0.0695 |

# %% [markdown]
# ## 유틸 함수 지도
#
# 튜토리얼에서 자주 쓰는 시각화/리포트 유틸은 `src.utils.visualize`, `src.utils.report`에 모여 있다.
#
# ### `src.utils.visualize`
#
# | 함수 | 용도 | 대표 입력 |
# |---|---|---|
# | `plot_training_curves` | Stage 1 학습 loss / mAP 곡선 확인 | `results.csv` |
# | `plot_s1_gt_vs_pred` | Stage 1 GT bbox와 예측 bbox 비교 | `predictions`, val image/label dir |
# | `plot_crop_showcase` | 탐지 수가 많은 이미지 1장의 원본 + crop 나열 | inference manifest, crop dir, image dir |
# | `plot_crop_grid` | crop 이미지 랜덤 샘플 그리드 확인 | crop dir |
# | `plot_pipeline_overlay` | 원본 이미지 위에 bbox + Stage 2 class overlay | `pipeline_by_img`, image dir |
# | `plot_pipeline_strip` | 원본 + crop + 분류 결과를 한 줄 스트립으로 확인 | `pipeline_by_img`, crop dir, image dir |
#
# ### `src.utils.report`
#
# | 함수 | 용도 | 대표 입력 |
# |---|---|---|
# | `load_timings` | `timings.json`을 dict로 로드 | experiment dir |
# | `print_timings` | Stage 1 / crop / Stage 2 / pipeline 소요 시간 요약 | experiment dir |
# | `load_s1_best_metrics` | `results.csv`에서 best Stage 1 지표 로드 | `results.csv` |
# | `load_s2_best_metrics` | Stage 2 checkpoint에서 best 지표 로드 | `best.pt` |
#
# 간단 사용 예:
#
# ```python
# import importlib
# import src.utils.visualize as viz
# from src.utils import report
#
# importlib.reload(viz)
#
# viz.plot_crop_grid(CROP_DIR, n=16)
# viz.plot_pipeline_strip(pipeline_by_img, CROP_DIR, VAL_IMG_DIR, save_dir=Path(f"experiments/{EXP_NAME}"))
#
# report.print_timings(Path(f"experiments/{EXP_NAME}"))
# print(report.load_s1_best_metrics(RESULTS_CSV))
# print(report.load_s2_best_metrics(BEST_PT_S2))
# ```

# %% [markdown]
# ## 📌 파이프라인 개요
#
# ### 왜 2-Stage 파이프라인인가?
#
# 1장의 약물 이미지에는 **여러 종류의 알약**이 섞여 있을 수 있습니다.
# - **Stage 1 (탐지)**: "어디에 알약이 있는가?" → 각 알약의 위치(bbox) 찾기
# - **Stage 2 (분류)**: "이것이 무엇인가?" → 찾은 각 알약의 약품명 분류
#
# ### 전체 흐름
#
# ```
# 원본 이미지
#     ↓
# [Stage 1: YOLO26n 탐지]
#   · 학습: 약물 위치 annotation으로 학습
#   · 추론: 이미지 → bbox 리스트
#     ↓
# [Stage 2: ResNet50 분류]
#   · 학습: bbox를 crop한 이미지 + 약품명 label로 학습
#   · 추론: 각 crop → 약품명 예측
#     ↓
# 최종 결과: [약물위치, 약품명, 신뢰도]
# ```
#
# ### 입출력 형식
#
# | 단계 | 입력 | 출력 | 형식 |
# |------|------|------|------|
# | **Stage 1 학습** | `data/processed/images/train/*.jpg` + YOLO format labels | 모델 가중치 | `.pt` |
# | **Stage 1 추론** | `data/processed/images/val/*.jpg` | `predictions.json` | `{"image_id", "detections": [{bbox, score}]}` |
# | **Stage 2 학습** | Crop 이미지 + 분류 label | 분류기 가중치 | `.pt` |
# | **Stage 2 추론** | Crop 이미지 | `predictions.json` | `{"crop_id", "class_name", "score"}` |
#
# ---

# %% [markdown]
# ## ⚙️ 1. 환경 설정
#
# 먼저 작업 디렉토리와 필수 라이브러리를 로드합니다.

# %%
import os
from pathlib import Path

# 프로젝트 루트 설정
_cwd = Path.cwd()
PROJECT_ROOT = _cwd if (_cwd / "experiments").exists() else _cwd.parent
os.chdir(PROJECT_ROOT)

try:
    import src  # noqa: F401
except ModuleNotFoundError as exc:
    raise RuntimeError(
        "현재 커널에서 src 패키지를 찾을 수 없습니다. "
        "프로젝트 루트(Main)에서 'pip install -e .'를 실행한 뒤 "
        "노트북 커널을 재시작하세요."
    ) from exc

print(f"✓ 작업 디렉토리: {os.getcwd()}")
print("✓ editable install import 확인: from src... 사용 가능")
# Out:
# ✓ 작업 디렉토리: /home/n132/Projects/Project1/codeit-part2-2team-project
# ✓ editable install import 확인: from src... 사용 가능

# %%
# 시각화·분석용 라이브러리
try:
    import koreanize_matplotlib  # noqa: F401
except ImportError:
    import subprocess

    subprocess.run(["pip", "install", "-q", "koreanize-matplotlib"])
    import koreanize_matplotlib  # noqa: F401, E402

import json
import random
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import yaml
import pandas as pd
from PIL import Image
import subprocess, sys

print("✓ 모든 라이브러리 로드 완료")
# Out:
# ✓ 모든 라이브러리 로드 완료

# %% [markdown]
# ## 2️⃣ 경로 및 설정 확인
#
# 학습과 추론에 사용할 설정 파일, 데이터 경로, 출력 디렉토리를 정의합니다.

# %%
# ============ 경로 변수 (수정하지 말 것) ============
# 실험 이름
EXP_NAME = "exp_20260503_efficientnet-b2"

# 설정 파일 경로
S1_CONFIG = f"experiments/{EXP_NAME}/s1_config.yaml"  # Stage 1 설정
S2_CONFIG = f"experiments/{EXP_NAME}/s2_config.yaml"  # Stage 2 설정 (efficientnet_b2 + HPO trial_0008)
DATA_YAML = "data/processed/dataset.yaml"  # 데이터셋 정의
VAL_IMG_DIR = Path("data/processed/images/val")  # val 원본 이미지
VAL_LABEL_DIR = Path("data/processed/labels/val")  # val YOLO 라벨

# 모델 가중치 경로
# Stage 1은 baseline 가중치 재사용
BEST_PT_S1 = "experiments/exp_20260420_baseline_yolo26n/weights/best.pt"  # Stage 1 best 모델
BEST_PT_S2 = f"experiments/{EXP_NAME}/stage2/weights/best.pt"  # Stage 2 best 모델

# 입출력 경로
RESULTS_CSV = f"experiments/{EXP_NAME}/results.csv"  # Stage 1 학습 로그
PRED_OUTPUT = f"experiments/{EXP_NAME}/val_predictions.json"  # Stage 1 추론 결과
CROP_DIR = Path(f"experiments/{EXP_NAME}/stage1_crops")  # Stage 1 추론 crop (시각화용)
GT_CROP_DIR = Path("data/processed/crops")  # GT crop (Stage 2 학습용)
S2_PRED_OUTPUT = f"experiments/{EXP_NAME}/stage2_predictions.json"  # Stage 2 추론 결과
UNKNOWN_CLASS_MAP = Path("data/processed/kaggle_unknown_class_map.json")  # Stage 2 alias → Kaggle canonical class

# ============ 경로 존재 확인 ============
paths_to_check = {
    "S1 설정": S1_CONFIG,
    "S2 설정": S2_CONFIG,
    "데이터": DATA_YAML,
    "val 이미지": str(VAL_IMG_DIR),
    "val 라벨": str(VAL_LABEL_DIR),
    "GT crop": str(GT_CROP_DIR),
}

print("\n경로 확인:")
print("-" * 50)
for name, path in paths_to_check.items():
    exists = "✓" if Path(path).exists() else "✗"
    print(f"{exists} {name:15s}: {path}")
print("-" * 50)
# Out:
# 경로 확인:
# --------------------------------------------------
# ✓ S1 설정          : experiments/exp_20260503_efficientnet-b2/s1_config.yaml
# ✓ S2 설정          : experiments/exp_20260503_efficientnet-b2/s2_config.yaml
# ✓ 데이터            : data/processed/dataset.yaml
# ✓ val 이미지        : data/processed/images/val
# ✓ val 라벨         : data/processed/labels/val
# ✓ GT crop        : data/processed/crops
# --------------------------------------------------

# %%
# Run All 시 학습을 건너뛰려면 False 유지, 재학습 시에만 True로 변경
RUN_TRAIN_S1 = False
RUN_TRAIN_S2 = False   # efficientnet_b2 신규 학습

print(f'RUN_TRAIN_S1 = {RUN_TRAIN_S1}')
print(f'RUN_TRAIN_S2 = {RUN_TRAIN_S2}')
# Out:
# RUN_TRAIN_S1 = False
# RUN_TRAIN_S2 = False

# %% [markdown]
# ### 설정 파일 확인
#
# **Stage 1 설정** — YOLO26n 모델 학습 파라미터:

# %%
with open(S1_CONFIG) as f:
    cfg = yaml.safe_load(f)

# 핵심 설정만 출력
print("\n📋 Stage 1 주요 설정:")
print("-" * 50)
print(f"  모델: {cfg['model']['name']}")
print(f"  이미지 크기: {cfg['data']['imgsz']}x{cfg['data']['imgsz']}")
print(f"  에포크: {cfg['train']['epochs']}")
print(f"  배치 크기: {cfg['train']['batch']}")
print(f"  Seed: {cfg['seed']} (재현성 보장)")
print("-" * 50)
# Out:
# 📋 Stage 1 주요 설정:
# --------------------------------------------------
#   모델: yolo26n
#   이미지 크기: 640x640
#   에포크: 100
#   배치 크기: 16
#   Seed: 42 (재현성 보장)
# --------------------------------------------------

# %% [markdown]
# ### 데이터셋 확인
#
# YOLO 형식 데이터셋 구조:
# - **Train**: 학습용 이미지 + YOLO format label
# - **Val**: 검증용 이미지 (파이프라인 시각화용)
# - **Test**: 최종 테스트 (kaggle 제출용)

# %%
with open(DATA_YAML) as f:
    data_cfg = yaml.safe_load(f)

DATA_YAML_DIR = Path(DATA_YAML).parent

print("\n📊 데이터셋 구성:")
print("-" * 50)
for split in ["train", "val", "test"]:
    p = (DATA_YAML_DIR / data_cfg[split]).resolve()
    count = (
        len(list(p.glob("*.jpg"))) + len(list(p.glob("*.png"))) if p.exists() else -1
    )
    status = "✓" if p.exists() else "✗"
    print(f"{status} {split:6s}: {count:4d} images  →  {p}")

VAL_IMG_DIR = (DATA_YAML_DIR / data_cfg["val"]).resolve()
print("-" * 50)
# Out:
# 📊 데이터셋 구성:
# --------------------------------------------------
# ✓ train : 3981 images  →  /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/train
# ✓ val   :  497 images  →  /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/val
# ✓ test  :  499 images  →  /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/test
# --------------------------------------------------

# %% [markdown]
# ---
#
# ## 🎯 Stage 1: 약물 탐지 모델 학습
#
# ### Step 1-1: 모델 학습
#
# YOLO26n을 약물 탐지 데이터로 학습합니다.
#
# **입력**: `data/processed/images/train/` (학습 이미지)
# **출력**: `experiments/{EXP_NAME}/weights/best.pt` (최고 성능 모델)
#
# 실행 시간: GPU 기준 ~10분
#
# ```bash
# # 코드 해설:
# # - train.py: 학습 스크립트
# # - --config: 위에서 확인한 설정 파일
# # - --data: 데이터셋 yaml 파일
# ```

# %%
import subprocess, sys

print('\n🚀 Stage 1 학습...')
print('=' * 50)
if RUN_TRAIN_S1:
    subprocess.run(
        [sys.executable, 'scripts/train.py',
         '--config', S1_CONFIG,
         '--data',   DATA_YAML],
        check=True
    )
    print('✓ Stage 1 학습 완료')
else:
    print('⏭  학습 스킵 (RUN_TRAIN_S1=False)')
# Out:
# 🚀 Stage 1 학습...
# ==================================================
# ⏭  학습 스킵 (RUN_TRAIN_S1=False)

# %% [markdown]
# ### Step 1-2: 모델 검증
#
# 학습된 모델을 검증 데이터에서 평가합니다.
#
# **메트릭**:
# - **Precision (P)**: 탐지한 것 중 정답 비율
# - **Recall (R)**: 정답 중 탐지한 비율
# - **mAP50**: IoU 0.5 기준 평균 정밀도 (일반적)
# - **mAP50-95**: IoU 0.5~0.95 기준 평균 정밀도 (엄격함)
#
# 목표: mAP50 > 0.95, mAP50-95 > 0.90

# %%
# Stage 1 검증 실행
print("\n🔍 Stage 1 검증 실행...")
print("=" * 50)
# !python scripts/validate.py \
    --config  {S1_CONFIG} \
    --data    {DATA_YAML}
print("=" * 50)
print("✓ Stage 1 검증 완료\n")
# Out:
# 🔍 Stage 1 검증 실행...
# ==================================================
# Ultralytics 8.4.39 🚀 Python-3.12.13 torch-2.11.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# YOLO26n summary (fused): 122 layers, 2,375,031 parameters, 0 gradients, 5.2 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2533.6±367.1 MB/s, size: 51.4 KB)
# val: Scanning /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/labels/val.cache... 497 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 497/497 122.6Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.3it/s 5.1s0.1s
#                    all        497        547      0.996      0.998      0.994      0.934
# Speed: 1.6ms preprocess, 3.3ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/n132/Projects/Project1/codeit-part2-2team-project/runs/detect/val-40
# ⏱  s1_validate: 6.6초
# mAP50=0.9938  mAP50-95=0.9339
# ==================================================
# ✓ Stage 1 검증 완료

# %% [markdown]
# ### Step 1-3: 학습 곡선 시각화
#
# Loss와 mAP 추이를 확인하여 모델 수렴성을 판단합니다.

# %%
from src.utils.visualize import plot_training_curves

# 경로 변수 셀을 건너뛰고 실행한 경우를 위한 fallback
if "RESULTS_CSV" not in globals():
    RESULTS_CSV = f"experiments/{EXP_NAME}/results.csv"

if Path(RESULTS_CSV).exists():
    plot_training_curves(RESULTS_CSV, save_dir=Path(f"experiments/{EXP_NAME}"))
else:
    print(f"⚠️ results.csv 없음: {RESULTS_CSV}")
    print("   Stage 1 학습 셀을 실행했거나, 실험 경로가 맞는지 확인하세요.")
# Out:
# ⚠️ results.csv 없음: experiments/exp_20260503_efficientnet-b2/results.csv
#    Stage 1 학습 셀을 실행했거나, 실험 경로가 맞는지 확인하세요.

# %% [markdown]
# ### Step 1-4: 추론 실행
#
# 학습된 모델로 검증 데이터에 대해 추론을 수행합니다.
#
# **출력**: `val_predictions.json`
# ```json
# {
#   "image_id": "...",
#   "detections": [
#     {"bbox": [x1, y1, x2, y2], "score": 0.95},
#     ...
#   ]
# }
# ```
#
# 이 결과를 Stage 2 입력으로 사용합니다.

# %%
print("\n🔮 Stage 1 추론 실행...")
print("=" * 50)
# !python scripts/predict.py \
    --config  {S1_CONFIG} \
    --source  {VAL_IMG_DIR} \
    --output  {PRED_OUTPUT}
print("=" * 50)

# 결과 통계
with open(PRED_OUTPUT) as f:
    predictions = json.load(f)

total_det = sum(len(p["detections"]) for p in predictions)
avg_det = total_det / max(len(predictions), 1)

print("\n📊 추론 결과 통계:")
print(f"  이미지 수: {len(predictions)}장")
print(f"  총 탐지: {total_det}개")
print(f"  평균 탐지: {avg_det:.2f}개/장")
print()
# Out:
# 🔮 Stage 1 추론 실행...
# ==================================================
#
# image 1/497 /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/val/ext_125mg-Madopar-HBS-cap-_jpg.rf.1816183d8912e67d3a8e14f9204e5e02.jpg: 640x640 1 pill, 13.9ms
# image 2/497 /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/val/ext_125mg-Madopar-HBS-cap_12_jpg.rf.6056b05c6f5934678b2415423b11dc14.jpg: 640x640 1 pill, 13.4ms
# image 3/497 /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/val/ext_20230316_074544051_iOS_jpg.rf.45b1ee23f3d21d0fb618c81544727e2f.jpg: 640x640 1 pill, 11.8ms
# image 4/497 /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/val/ext_20230316_075432749_iOS_jpg.rf.7935e9ef2b6e81da4ee5e506d8e17302.jpg: 640x640 1 pill, 12.8ms
# image 5/497 /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/val/ext_20230316_080700940_iOS_jpg.rf.f4c87c380180c441af59107b651fe8fa.jpg: 640x640 1 pill, 12.0ms
# image 6/497 /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/val/ext_20230316_081348776_iOS_jpg.rf.3dfed0d7aac31c2a32f2bb6b764f3718.jpg: 640x640 1 pill, 12.2ms
# image 7/497 /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/val/ext_20230316_081420494_iOS_jpg.rf.6ddb9e01be932568fad55ee740cf43cc.jpg: 640x640 1 pill, 12.3ms
# image 8/497 /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/val/ext_20230316_081551871_iOS_jpg.rf.a8e7eaae4f82678aef674dc11071e221.jpg: 640x640 1 pill, 13.0ms
# image 9/497 /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/val/ext_20230316_081639910_iOS_jpg.rf.5928dbde26d486c360d04e9290876526.jpg: 640x640 1 pill, 12.1ms
# image 10/497 /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/val/ext_20230316_082343148_iOS_jpg.rf.1d7f59b1650ae24fefe859a8a71cc45e.jpg: 640x640 1 pill, 12.1ms
# image 11/497 /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/val/ext_20230316_082518470_iOS_jpg.rf.7a5a7cfd3fd8a5dd561aec643b49e0bf.jpg: 640x640 1 pill, 11.5ms
# image 12/497 /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/val/ext_
497 /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/val/raw_K-003351-019232-021325_0_2_0_2_75_000_200.png: 640x512 3 pills, 17.5ms
# image 489/497 /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/val/raw_K-003351-020014-021325_0_2_0_2_90_000_200.png: 640x512 3 pills, 17.6ms
# image 490/497 /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/val/raw_K-003351-020014-035206_0_2_0_2_90_000_200.png: 640x512 4 pills, 13.1ms
# image 491/497 /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/val/raw_K-003351-021325-033880_0_2_0_2_70_000_200.png: 640x512 3 pills, 11.7ms
# image 492/497 /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/val/raw_K-003351-021325-041768_0_2_0_2_75_000_200.png: 640x512 3 pills, 11.8ms
# image 493/497 /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/val/raw_K-003351-029667-033880_0_2_0_2_90_000_200.png: 640x512 3 pills, 15.0ms
# image 494/497 /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/val/raw_K-003351-031863-035206_0_2_0_2_75_000_200.png: 640x512 3 pills, 19.0ms
# image 495/497 /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/val/raw_K-003351-031863-038162_0_2_0_2_70_000_200.png: 640x512 3 pills, 11.7ms
# image 496/497 /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/val/raw_K-003483-020877-031885-036637_0_2_0_2_70_000_200.png: 640x512 4 pills, 14.4ms
# image 497/497 /home/n132/Projects/Project1/codeit-part2-2team-project/data/processed/images/val/raw_K-003483-025367-025469-035206_0_2_0_2_70_000_200.png: 640x512 4 pills, 12.4ms
# Speed: 2.2ms preprocess, 13.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
# ⏱  s1_predict: 10.8초
# 완료: 497개 이미지 → /home/n132/Projects/Project1/codeit-part2-2team-project/experiments/exp_20260503_efficientnet-b2/val_predictions.json
# ==================================================
#
# 📊 추론 결과 통계:
#   이미지 수: 497장
#   총 탐지: 554개
#   평균 탐지: 1.11개/장

# %% [markdown]
# ### Step 1-5: 결과 시각화 — 멀티 탐지 케이스
#
# GT(초록) vs 예측(빨강) 박스를 비교합니다. 알약 2개 이상인 이미지에서 모델 성능을 확인합니다.

# %%
from src.utils.visualize import plot_s1_gt_vs_pred

# 경로 변수 셀을 건너뛰고 실행한 경우를 위한 fallback
if "VAL_IMG_DIR" not in globals():
    VAL_IMG_DIR = Path("data/processed/images/val")
if "VAL_LABEL_DIR" not in globals():
    VAL_LABEL_DIR = Path("data/processed/labels/val")

if "predictions" not in globals():
    print("⚠️ predictions 없음 — Stage 1 추론 결과 로드/생성 셀을 먼저 실행하세요.")
elif not Path(VAL_IMG_DIR).exists():
    print(f"⚠️ val 이미지 디렉터리 없음: {VAL_IMG_DIR}")
elif not Path(VAL_LABEL_DIR).exists():
    print(f"⚠️ val 라벨 디렉터리 없음: {VAL_LABEL_DIR}")
else:
    plot_s1_gt_vs_pred(predictions, VAL_IMG_DIR, VAL_LABEL_DIR)
# Out:
# 멀티 알약 이미지: 23개 / 전체 497개

# %% [markdown]
# ### Step 1-6: Crop 추출
#
# Stage 1 추론 결과의 bbox를 기준으로 이미지를 잘라냅니다. 이 crop은 Stage 2 입력으로 사용됩니다.
#
# **입력**: `val_predictions.json`, 원본 이미지
# **출력**: `stage1_crops/` (개별 crop 이미지들), `crops_manifest.json` (메타데이터)

# %%
print("\n✂️  Crop 추출 중...")
print("=" * 50)
# !python scripts/pipeline/crop.py \
    --predictions {PRED_OUTPUT} \
    --source      {VAL_IMG_DIR} \
    --output      {CROP_DIR} \
    --padding     0.05
print("=" * 50)

# Crop 통계
with open(CROP_DIR / "crops_manifest.json") as f:
    manifest = json.load(f)

print(f"\n✓ Crop 추출 완료: {len(manifest)}개 이미지")
# Out:
# ✂️  Crop 추출 중...
# ==================================================
# ⏱  crop: 1.2초
# 크롭 완료: 554개 → experiments/exp_20260503_efficientnet-b2/stage1_crops
# ==================================================
#
# ✓ Crop 추출 완료: 554개 이미지

# %% [markdown]
# ### Manifest 역할 정리
#
# 이 튜토리얼에서는 crop manifest를 용도별로 분리해서 사용한다.
#
# | manifest 종류 | 생성 모드 | 주요 필드 | 용도 |
# |---|---|---|---|
# | GT crop manifest | `crop.py --labels ... --images ...` 또는 이미 준비된 crop manifest | `crop_path`, `class_name`, 선택적으로 `image_id`, `bbox` | Stage 2 학습/분류 평가 |
# | ImageFolder manifest | `crop.py --imagefolder ...` | `crop_path`, `class_name` | 이미 잘린 crop을 Stage 2 학습 인터페이스에 연결 |
# | Inference crop manifest | `crop.py --predictions ... --source ...` | `crop_id`, `image_id`, `bbox`, `score` | 복원 시각화, e2e 평가, Kaggle 제출 |
#
# Kaggle 제출에는 반드시 `data/test`에서 Stage 1 예측으로 만든 inference crop manifest를 사용한다. GT crop manifest나 ImageFolder manifest는 제출 입력으로 쓰지 않는다.

# %% [markdown]
# ### Step 1-7: Crop 품질 확인
#
# 탐지한 알약들이 제대로 crop되었는지 시각적으로 확인합니다.

# %%
from src.utils.visualize import plot_crop_showcase

plot_crop_showcase(manifest, CROP_DIR, VAL_IMG_DIR)

# %% [markdown]
# ---
#
# ## 🎯 Stage 2: 약물 분류 모델
#
# ### Step 2-0: GT Crop 생성 (최초 1회)
#
# Stage 2 학습을 위해 GT label 기반 crop을 생성합니다. 이미 존재하면 건너뜁니다.
#
# **출력**: `data/processed/crops/{train,val}/`

# %%
print("\n📦 GT Crop 생성 (또는 로드)...")
print("=" * 50)

if not (GT_CROP_DIR / "train" / "crops_manifest.json").exists():
    print("⏳ 첫 실행 — GT crop 생성 중... (1-2분)")
    # !python scripts/pipeline/crop.py \
        --imagefolder data/processed/crops \
        --splits      train val
else:
    import json
    with open(GT_CROP_DIR / "train" / "crops_manifest.json") as f:
        gt_manifest = json.load(f)
    print("✓ GT crop 이미 존재")
    print(f"  Train: {len(gt_manifest)}개 crop")
    
    with open(GT_CROP_DIR / "val" / "crops_manifest.json") as f:
        gt_manifest_val = json.load(f)
    print(f"  Val: {len(gt_manifest_val)}개 crop")

print("=" * 50)
# Out:
# 📦 GT Crop 생성 (또는 로드)...
# ==================================================
# ✓ GT crop 이미 존재
#   Train: 15525개 crop
#   Val: 824개 crop
# ==================================================

# %% [markdown]
# ### Step 2-1: 분류 모델 학습
#
# GT crop 이미지들로 약품명 분류 모델(**efficientnet_b2**, HPO trial_0008)을 학습합니다.
#
# **입력**: `data/processed/crops/{train,val}/` (crop 이미지 + 폴더명 = class)
# **출력**: `experiments/exp_20260503_efficientnet-b2/stage2/weights/best.pt`
#
# 학습 시간: GPU 기준 ~10분

# %%
print('\n🚀 Stage 2 분류기 학습...')
print('=' * 50)
if RUN_TRAIN_S2:
    subprocess.run(
        [sys.executable, 'scripts/pipeline/stage2_train.py',
         '--config', S2_CONFIG],
        check=True
    )
    print('✓ Stage 2 학습 완료')
else:
    print('⏭  학습 스킵 (RUN_TRAIN_S2=False)')
# Out:
# 🚀 Stage 2 분류기 학습...
# ==================================================
# ⏭  학습 스킵 (RUN_TRAIN_S2=False)

# %%
# Stage 2 체크포인트 지표 확인
import torch

if not Path(BEST_PT_S2).exists():
    print('⚠️  가중치 없음 — Step 2-1 학습을 먼저 실행하세요')
else:
    _ck = torch.load(BEST_PT_S2, map_location='cpu')
    _metrics = _ck.get('metrics', {})
    _nc = len(_ck.get('class_names', []))
    print(f'Stage 2  best epoch : {_ck["epoch"] + 1}')
    print(f'  Top-1 Acc         : {_metrics.get("top1_acc", _ck.get("top1_acc", "N/A"))}')
    print(f'  Top-5 Acc         : {_metrics.get("top5_acc", _ck.get("top5_acc", "N/A"))}')
    print(f'  학습 클래스 수    : {_nc}')
# Out:
# Stage 2  best epoch : 94
#   Top-1 Acc         : 0.8932038834951457
#   Top-5 Acc         : 0.9696601941747572
#   학습 클래스 수    : 305

# %% [markdown]
# ### Step 2-2: 분류 추론
#
# Stage 1에서 추출한 crop 이미지들을 분류합니다.
#
# **입력**: `stage1_crops/*.jpg`
# **출력**: `stage2_predictions.json`
# ```json
# {
#   "crop_id": "...",
#   "class_name": "아스피린",
#   "score": 0.92
# }
# ```

# %%
print("\n🔮 Stage 2 추론 실행...")
print("=" * 50)

if not Path(BEST_PT_S2).exists():
    print("⚠️  Stage 2 모델 가중치 없음 — Step 2-1을 먼저 실행하세요")
else:
    # !python scripts/pipeline/stage2_predict.py \
        --config  {S2_CONFIG} \
        --weights {BEST_PT_S2} \
        --source  {CROP_DIR} \
        --output  {S2_PRED_OUTPUT}

print("=" * 50)
print()
# Out:
# 🔮 Stage 2 추론 실행...
# ==================================================
# ⏱  s2_predict: 2.0초
# 추론 완료: 554개 → experiments/exp_20260503_efficientnet-b2/stage2_predictions.json
# ==================================================

# %% [markdown]
# ### Step 2-3: End-to-end mAP 평가
#
# `evaluate_pipeline.py`는 GT label + Stage 1 crops manifest + Stage 2 predictions를 받아
# 파이프라인 전체의 **e2e mAP**를 계산한다.
#
# | 지표 | 설명 |
# |------|------|
# | `mAP@[0.50:0.95]` | COCO 표준 지표 |
# | `mAP@[0.75:0.95]` | **Kaggle 제출 평가 지표** (엄격한 IoU 기준) |
# | `mAP@0.50` | 전통적 Pascal VOC 지표 |
#
# > score = `det_score` (crops_manifest) × `cls_score` (stage2_predictions)
#
# 주의:
# - GT bbox는 YOLO label에서 읽는다.
# - YOLO label은 Stage 1용 `pill=0` 단일 클래스라 GT 약품명을 담고 있지 않다.
# - evaluator는 GT crop manifest, Roboflow source key, `raw_K-*` 파일명의 category id로 GT class를 복원한다.
# - `--unknown-class-map`은 Stage 2 alias 예측명을 Kaggle canonical class name으로 맞춰 평가한다.
#
# ```bash
# python scripts/pipeline/evaluate_pipeline.py \
#     --gt-labels data/processed/labels/val \
#     --gt-images data/processed/images/val \
#     --s1-crops  experiments/{EXP}/stage1_crops/crops_manifest.json \
#     --s2-preds  experiments/{EXP}/stage2_predictions.json
#
# # Kaggle canonical class 기준 평가 + Stage 2 alias 정규화
# python scripts/pipeline/evaluate_pipeline.py \
#     --gt-labels data/processed/labels/val \
#     --gt-images data/processed/images/val \
#     --s1-crops  experiments/{EXP}/stage1_crops/crops_manifest.json \
#     --s2-preds  experiments/{EXP}/stage2_predictions.json \
#     --kaggle-classes data/processed/kaggle_class_map.json \
#     --unknown-class-map data/processed/kaggle_unknown_class_map.json
#
# # 클래스별 AP 상위 20개 추가 출력
# python scripts/pipeline/evaluate_pipeline.py ... --per-class
# ```

# %%
def _parse_eval_stdout(stdout):
    out = {}
    for line in stdout.splitlines():
        if 'Pred' in line and '클래스 평가' in line:
            try:
                out['n_eval_classes'] = int(line.split('/')[1].split('클래스')[0].strip())
            except (IndexError, ValueError):
                pass
        if 'mAP@[0.50:0.95]' in line:
            out['mAP50_95'] = float(line.split(':')[-1].strip().split()[0])
        if 'mAP@[0.75:0.95]' in line:
            out['mAP75_95'] = float(line.split(':')[-1].strip().split()[0])
        if 'mAP@0.50 ' in line:
            out['mAP50'] = float(line.split(':')[-1].strip())
        if 'mAP@0.75 ' in line:
            out['mAP75'] = float(line.split(':')[-1].strip())
    return out

MANIFEST_PATH = str(CROP_DIR / 'crops_manifest.json')
_VAL_LABEL_DIR = 'data/processed/labels/val'
_VAL_IMG_DIR   = 'data/processed/images/val'
KAGGLE_CLASS_MAP = 'data/processed/kaggle_class_map.json'

if not Path(MANIFEST_PATH).exists():
    print('⚠️  crops_manifest.json 없음 — Step 1-6 crop 추출을 먼저 실행하세요')
elif not Path(S2_PRED_OUTPUT).exists():
    print('⚠️  stage2_predictions.json 없음 — Step 2-2 추론을 먼저 실행하세요')
else:
    # Stage 2 GT val 크롭 정확도 (Stage 1 탐지 오차 없는 상한선)
    _val_gt_manifest = GT_CROP_DIR / 'val' / 'crops_manifest.json'
    VAL_GT_S2_PREDS = f"experiments/{EXP_NAME}/val_s2_predictions_gt.json"
    if not Path(VAL_GT_S2_PREDS).exists():
        subprocess.run(
            [sys.executable, 'scripts/pipeline/stage2_predict.py',
             '--config', S2_CONFIG, '--weights', BEST_PT_S2,
             '--source', str(GT_CROP_DIR / 'val'),
             '--output', VAL_GT_S2_PREDS],
            check=True
        )
    with open(_val_gt_manifest) as f:
        _val_gt_map = {r['crop_id']: r['class_name'] for r in json.load(f)}
    with open(VAL_GT_S2_PREDS) as f:
        _val_gt_preds = json.load(f)
    _val_top1  = sum(1 for p in _val_gt_preds if _val_gt_map.get(p['crop_id']) == p['class_name'])
    _val_total = sum(1 for p in _val_gt_preds if p['crop_id'] in _val_gt_map)

    # E2E mAP 평가
    _cmd_base = [
        sys.executable, 'scripts/pipeline/evaluate_pipeline.py',
        '--gt-labels', _VAL_LABEL_DIR,
        '--gt-images', _VAL_IMG_DIR,
        '--s1-crops',  MANIFEST_PATH,
        '--s2-preds',  S2_PRED_OUTPUT,
    ]
    r_val_internal = subprocess.run(_cmd_base, capture_output=True, text=True)
    r_val_kaggle = subprocess.run(
        _cmd_base + ['--kaggle-classes', KAGGLE_CLASS_MAP,
                     '--unknown-class-map', str(UNKNOWN_CLASS_MAP)],
        capture_output=True, text=True
    )

    VAL_E2E_INTERNAL = _parse_eval_stdout(r_val_internal.stdout)
    VAL_E2E_KAGGLE   = _parse_eval_stdout(r_val_kaggle.stdout)
    VAL_GT_TOP1 = _val_top1 / _val_total if _val_total else None

    print('[val — 내부 기준]')
    print(r_val_internal.stdout)
    if r_val_internal.returncode != 0:
        print('[stderr]', r_val_internal.stderr[:300])

    print('[val — Kaggle 기준]')
    print(r_val_kaggle.stdout)
    if r_val_kaggle.returncode != 0:
        print('[stderr]', r_val_kaggle.stderr[:300])

    print(f"  Stage 2 GT val 정확도: {VAL_GT_TOP1:.4f}  ({_val_top1}/{_val_total})")
# Out:
# [val — 내부 기준]
# GT     : 497장  547개 객체
# Pred   : 554개 / 207클래스 평가  [Stage 2 학습 클래스 기준]
# mAP@[0.50:0.95] : 0.8007  (COCO)
# mAP@[0.75:0.95] : 0.7503  (Kaggle)
# mAP@0.50        : 0.8510
# mAP@0.75        : 0.8510
#
# [val — Kaggle 기준]
# GT     : 497장  547개 객체
# Pred   : 554개 / 34클래스 평가  [Kaggle 클래스 기준]
# mAP@[0.50:0.95] : 0.9225  (COCO)
# mAP@[0.75:0.95] : 0.9065  (Kaggle)
# mAP@0.50        : 0.9384
# mAP@0.75        : 0.9384
#
#   Stage 2 GT val 정확도: 0.8932  (736/824)

# %% [markdown]
# ### Step 2-4: Test E2E 평가 (data/processed/images/test 기준)

# %%
# Test E2E 평가 파이프라인 (data/processed/images/test 기준 — Kaggle 제출용 data/test와 별개)
RUN_EVAL_TEST = True   # False면 기존 결과 파일 재사용

_TEST_IMG_DIR   = Path("data/processed/images/test")
_TEST_LABEL_DIR = "data/processed/labels/test"
TEST_S1_PREDS_E2E = f"experiments/{EXP_NAME}/test_s1_predictions.json"
TEST_S1_CROPS     = Path(f"experiments/{EXP_NAME}/test_s1_crops")
TEST_S2_PREDS_E2E = f"experiments/{EXP_NAME}/test_s2_predictions_e2e.json"

if RUN_EVAL_TEST and not Path(TEST_S2_PREDS_E2E).exists():
    subprocess.run(
        [sys.executable, 'scripts/predict.py',
         '--config',  S1_CONFIG, '--weights', BEST_PT_S1,
         '--source',  str(_TEST_IMG_DIR),
         '--output',  TEST_S1_PREDS_E2E],
        check=True
    )
    subprocess.run(
        [sys.executable, 'scripts/pipeline/crop.py',
         '--predictions', TEST_S1_PREDS_E2E,
         '--source',      str(_TEST_IMG_DIR),
         '--output',      str(TEST_S1_CROPS)],
        check=True
    )
    subprocess.run(
        [sys.executable, 'scripts/pipeline/stage2_predict.py',
         '--config',  S2_CONFIG, '--weights', BEST_PT_S2,
         '--source',  str(TEST_S1_CROPS),
         '--output',  TEST_S2_PREDS_E2E],
        check=True
    )
else:
    print('⏭  test pipeline 스킵 — 기존 파일 재사용')

with open(TEST_S1_CROPS / 'crops_manifest.json') as f:
    _test_crops = json.load(f)
print(f'test S1 크롭: {len(_test_crops)}개')

# Stage 2 GT test 크롭 정확도 (탐지 오차 없는 상한선)
_test_gt_manifest = GT_CROP_DIR / 'test' / 'crops_manifest.json'
if not _test_gt_manifest.exists():
    subprocess.run(
        [sys.executable, 'scripts/pipeline/crop.py',
         '--imagefolder', str(GT_CROP_DIR),
         '--splits', 'test'],
        check=True
    )
TEST_GT_S2_PREDS = f"experiments/{EXP_NAME}/test_s2_predictions.json"
if not Path(TEST_GT_S2_PREDS).exists():
    subprocess.run(
        [sys.executable, 'scripts/pipeline/stage2_predict.py',
         '--config',  S2_CONFIG, '--weights', BEST_PT_S2,
         '--source',  str(GT_CROP_DIR / 'test'),
         '--output',  TEST_GT_S2_PREDS],
        check=True
    )
with open(_test_gt_manifest) as f:
    _test_gt_map = {r['crop_id']: r['class_name'] for r in json.load(f)}
with open(TEST_GT_S2_PREDS) as f:
    _test_gt_preds = json.load(f)
_test_top1  = sum(1 for p in _test_gt_preds if _test_gt_map.get(p['crop_id']) == p['class_name'])
_test_total = sum(1 for p in _test_gt_preds if p['crop_id'] in _test_gt_map)
TEST_GT_TOP1 = _test_top1 / _test_total if _test_total else None
print(f"Stage 2 GT test 정확도: {TEST_GT_TOP1:.4f}  ({_test_top1}/{_test_total})")
if 'VAL_GT_TOP1' in globals() and VAL_GT_TOP1 is not None:
    print(f"  비교  : val GT 크롭 Top-1 = {VAL_GT_TOP1:.4f}")

# E2E mAP
r_test_internal = subprocess.run(
    [sys.executable, 'scripts/pipeline/evaluate_pipeline.py',
     '--gt-labels', _TEST_LABEL_DIR,
     '--gt-images', str(_TEST_IMG_DIR),
     '--s1-crops',  str(TEST_S1_CROPS / 'crops_manifest.json'),
     '--s2-preds',  TEST_S2_PREDS_E2E],
    capture_output=True, text=True
)
r_test_kaggle = subprocess.run(
    [sys.executable, 'scripts/pipeline/evaluate_pipeline.py',
     '--gt-labels', _TEST_LABEL_DIR,
     '--gt-images', str(_TEST_IMG_DIR),
     '--s1-crops',  str(TEST_S1_CROPS / 'crops_manifest.json'),
     '--s2-preds',  TEST_S2_PREDS_E2E,
     '--kaggle-classes', KAGGLE_CLASS_MAP,
     '--unknown-class-map', str(UNKNOWN_CLASS_MAP)],
    capture_output=True, text=True
)
TEST_E2E_INTERNAL = _parse_eval_stdout(r_test_internal.stdout)
TEST_E2E_KAGGLE   = _parse_eval_stdout(r_test_kaggle.stdout)

print('[test — 내부 기준]')
print(r_test_internal.stdout)
if r_test_internal.returncode != 0:
    print('[stderr]', r_test_internal.stderr[:300])
print('[test — Kaggle 기준]')
print(r_test_kaggle.stdout)
if r_test_kaggle.returncode != 0:
    print('[stderr]', r_test_kaggle.stderr[:300])
# Out:
# ⏭  test pipeline 스킵 — 기존 파일 재사용
# test S1 크롭: 564개
# Stage 2 GT test 정확도: 0.8783  (1018/1159)
#   비교  : val GT 크롭 Top-1 = 0.8932
# [test — 내부 기준]
# GT     : 499장  553개 객체
# Pred   : 564개 / 214클래스 평가  [Stage 2 학습 클래스 기준]
# mAP@[0.50:0.95] : 0.7996  (COCO)
# mAP@[0.75:0.95] : 0.7555  (Kaggle)
# mAP@0.50        : 0.8454
# mAP@0.75        : 0.8410
#
# [test — Kaggle 기준]
# GT     : 499장  553개 객체
# Pred   : 564개 / 38클래스 평가  [Kaggle 클래스 기준]
# mAP@[0.50:0.95] : 0.9128  (COCO)
# mAP@[0.75:0.95] : 0.9045  (Kaggle)
# mAP@0.50        : 0.9211
# mAP@0.75        : 0.9211

# %% [markdown]
# ## 📋 결과 요약

# %%
from src.utils.report import load_s1_best_metrics, load_s2_best_metrics, print_timings


def _fmt_metric(metrics, key, default='실행 필요'):
    if metrics is None or key not in metrics or metrics[key] is None:
        return f"{default:>9s}"
    return f"{metrics[key]:>9.4f}"


print("=" * 56)
print(f"  {EXP_NAME}")
print("=" * 56)
print(f"  model       : {cfg['model']['name']}")
print(f"  imgsz       : {cfg['data']['imgsz']}")
print(f"  S1 epochs   : {cfg['train']['epochs']}  /  batch {cfg['train']['batch']}")
print("-" * 56)
print("  [ Stage 1 Detection ]")
_s1_csv = f"experiments/{EXP_NAME}/results.csv"
if not Path(_s1_csv).exists():
    # Stage 1 가중치 재사용 — 원본 실험의 results.csv 사용
    _s1_csv = str(Path(BEST_PT_S1).parent.parent / "results.csv")
_s1m = load_s1_best_metrics(_s1_csv)
if _s1m:
    print(f"  best epoch  : {_s1m['epoch']}")
    print(f"  mAP50       : {_s1m['mAP50']:.4f}  (val)")
    print(f"  mAP50-95    : {_s1m['mAP50_95']:.4f}  (val)")
    if _s1_csv != f"experiments/{EXP_NAME}/results.csv":
        print(f"  (from: {Path(_s1_csv).parent.name})")
else:
    print("  (s1-metrics 셀 실행 필요)")
if 'total_det' in globals() and 'predictions' in globals():
    print(f"  총 탐지     : {total_det}개  ({total_det/max(len(predictions),1):.1f}/장)")
print("-" * 56)
print("  [ Stage 2 Classification ]")
_s2m = load_s2_best_metrics(BEST_PT_S2)
if _s2m:
    print(f"  best epoch  : {_s2m['epoch']}")
    print(f"  Top-1 Acc   : {_s2m['top1_acc']:.4f}  (val 크롭)")
    print(f"  Top-5 Acc   : {_s2m['top5_acc']:.4f}  (val 크롭)")
    print(f"  클래스 수   : {_s2m['n_classes']}")
else:
    print("  (s2-metrics 셀 실행 필요)")
print("-" * 56)
print("  [ E2E mAP — val / test ]")
_val_internal = globals().get('VAL_E2E_INTERNAL')
_val_kaggle = globals().get('VAL_E2E_KAGGLE')
_test_internal = globals().get('TEST_E2E_INTERNAL')
_test_kaggle = globals().get('TEST_E2E_KAGGLE')
print(f"  {'지표':<34s}  {'val':>9s}  {'test':>9s}")
print(f"  {'-'*56}")
print(
    f"  {'mAP@[0.75:0.95] 내부':<34s}"
    f"  {_fmt_metric(_val_internal, 'mAP75_95')}"
    f"  {_fmt_metric(_test_internal, 'mAP75_95')}"
)
print(
    f"  {'mAP@[0.75:0.95] Kaggle':<34s}"
    f"  {_fmt_metric(_val_kaggle, 'mAP75_95')}"
    f"  {_fmt_metric(_test_kaggle, 'mAP75_95')}"
)
print(
    f"  {'mAP@0.50 내부':<34s}"
    f"  {_fmt_metric(_val_internal, 'mAP50')}"
    f"  {_fmt_metric(_test_internal, 'mAP50')}"
)
print(
    f"  {'Kaggle 평가 클래스 수':<34s}"
    f"  {str(_val_kaggle.get('n_eval_classes', '실행 필요')) if _val_kaggle else '실행 필요':>9s}"
    f"  {str(_test_kaggle.get('n_eval_classes', '실행 필요')) if _test_kaggle else '실행 필요':>9s}"
)
_val_gt_top1 = globals().get('VAL_GT_TOP1')
_test_gt_top1 = globals().get('TEST_GT_TOP1')
print(
    f"  {'Stage 2 Top-1 (GT 크롭)':<34s}"
    f"  {(f'{_val_gt_top1:.4f}' if _val_gt_top1 is not None else '실행 필요'):>9s}"
    f"  {(f'{_test_gt_top1:.4f}' if _test_gt_top1 is not None else '실행 필요'):>9s}"
)
print("-" * 56)
print_timings(f"experiments/{EXP_NAME}")
print("=" * 56)
# Out:
# ========================================================
#   exp_20260503_efficientnet-b2
# ========================================================
#   model       : yolo26n
#   imgsz       : 640
#   S1 epochs   : 100  /  batch 16
# --------------------------------------------------------
#   [ Stage 1 Detection ]
#   best epoch  : 20
#   mAP50       : 0.9947  (val)
#   mAP50-95    : 0.8718  (val)
#   (from: exp_20260420_baseline_yolo26n)
#   총 탐지     : 554개  (1.1/장)
# --------------------------------------------------------
#   [ Stage 2 Classification ]
#   best epoch  : 94
#   Top-1 Acc   : 0.8932  (val 크롭)
#   Top-5 Acc   : 0.9697  (val 크롭)
#   클래스 수   : 305
# --------------------------------------------------------
#   [ E2E mAP — val / test ]
#   지표                                        val       test
#   --------------------------------------------------------
#   mAP@[0.75:0.95] 내부                     0.7503     0.7555
#   mAP@[0.75:0.95] Kaggle                 0.9065     0.9045
#   mAP@0.50 내부                            0.8510     0.8454
#   Kaggle 평가 클래스 수                            34         38
#   Stage 2 Top-1 (GT 크롭)                  0.8932     0.8783
# --------------------------------------------------------
#
# ⏱  소요 시간 요약
# ============================================
#   Crop 생성       :     1.2초  (0.0분)
#   S2 학습         :  9409.2초  (156.8분)
#   S2 추론         :     2.0초  (0.0분)
# ========================================================

# %% [markdown]
# ---
#
# ## 📊 2-Stage 통합 결과 시각화
#
# ### 최종 결과: 약물 위치 + 약품명 + 신뢰도

# %%
# Stage 1 inference manifest + Stage 2 predictions를 다시 로드해 통합 결과 구성
MANIFEST_PATH = str(CROP_DIR / "crops_manifest.json")

if not Path(MANIFEST_PATH).exists():
    print(f"⚠️ manifest 없음: {MANIFEST_PATH}")
elif not Path(S2_PRED_OUTPUT).exists():
    print("⚠️ Stage 2 추론 결과 없음 — Step 2-2를 먼저 실행하세요")
else:
    with open(MANIFEST_PATH, encoding="utf-8") as f:
        manifest = json.load(f)
    with open(S2_PRED_OUTPUT, encoding="utf-8") as f:
        s2_results = json.load(f)

    s2_by_crop = {r["crop_id"]: r for r in s2_results}
    pipeline_by_img = {}
    missing_s2 = 0
    for item in manifest:
        s2 = s2_by_crop.get(item["crop_id"])
        if s2 is None:
            missing_s2 += 1
            s2 = {}
        pipeline_by_img.setdefault(item["image_id"], []).append(
            {
                "bbox": item["bbox"],
                "det_score": item.get("score", 0.0),
                "crop_id": item["crop_id"],
                "class_name": s2.get("class_name", "?"),
                "class_score": s2.get("score", 0.0),
            }
        )

    multi_count = sum(1 for v in pipeline_by_img.values() if len(v) >= 2)
    print(f"✓ 통합 결과 준비 완료: {len(pipeline_by_img)}장 / crop {len(manifest)}개")
    print(f"  multi 탐지 이미지: {multi_count}장")
    print(f"  Stage 2 매칭 누락 crop: {missing_s2}개")
    print(f"  image_id 예시: {list(pipeline_by_img)[:3]}")
# Out:
# ✓ 통합 결과 준비 완료: 497장 / crop 554개
#   multi 탐지 이미지: 28장
#   Stage 2 매칭 누락 crop: 0개
#   image_id 예시: ['ext_125mg-Madopar-HBS-cap-_jpg.rf.1816183d8912e67d3a8e14f9204e5e02', 'ext_125mg-Madopar-HBS-cap_12_jpg.rf.6056b05c6f5934678b2415423b11dc14', 'ext_20230316_074544051_iOS_jpg.rf.45b1ee23f3d21d0fb618c81544727e2f']

# %% [markdown]
# ### 결과 1: 오버레이 시각화 — 멀티 탐지 케이스
#
# 약물 위치에 약품명을 직접 표시합니다.

# %%
import importlib
import src.utils.visualize as viz
importlib.reload(viz)

if "pipeline_by_img" not in globals():
    print("⚠️ pipeline_by_img 없음 — 바로 위 통합 결과 구성 셀을 먼저 실행하세요")
elif not Path(S2_PRED_OUTPUT).exists():
    print("⚠️ Stage 2 결과 없음")
else:
    # reload된 최신 함수 사용: 이미지가 없는 sample은 건너뛰고 원인을 출력한다.
    viz.plot_pipeline_overlay(
        pipeline_by_img,
        VAL_IMG_DIR,
        save_dir=Path(f"experiments/{EXP_NAME}"),
    )
# Out:
# 멀티 탐지 이미지: 28개 / 전체 497개
# ✓ 저장: experiments/exp_20260503_efficientnet-b2/pipeline_overlay.png

# %% [markdown]
# ## Kaggle test 제출 파일 생성
#
# `make_submission.py`는 inference `crops_manifest.json`과 Stage 2 predictions를 `crop_id`로 병합해 `submission.csv`를 만든다.
#
# 중요 규칙:
#
# - `--manifest`에는 test inference crop manifest를 넣는다.
# - `class_map` 밖 예측 클래스는 기본 제외한다.
# - 필요한 경우 `--unknown-class-map`으로 map 밖 예측을 Kaggle class name/category_id로 명시 치환한다.

# %%
print('\n📦 Kaggle test 제출 파일 생성...')
print('=' * 50)

TEST_IMG_DIR = Path('data/test')
TEST_S1_PREDS = Path('data/test/s1_predictions.json')
TEST_CROP_DIR = Path('data/test/s1_crops')
TEST_MANIFEST = TEST_CROP_DIR / 'crops_manifest.json'
TEST_S2_PREDS = Path('data/test/stage2_predictions.json')
SUBMISSION_OUTPUT = Path(f'submissions/{EXP_NAME}_submission2.csv')
CLASS_MAP = Path('data/processed/kaggle_class_map.json')
UNKNOWN_CLASS_MAP = Path('data/processed/kaggle_unknown_class_map.json')

required = {
    'data/test': TEST_IMG_DIR,
    'Stage 1 weights': Path(BEST_PT_S1),
    'Stage 2 weights': Path(BEST_PT_S2),
    'class map': CLASS_MAP,
}
missing = [name for name, path in required.items() if not path.exists()]
if missing:
    raise FileNotFoundError(f'필수 파일/디렉터리가 없습니다: {missing}')

SUBMISSION_OUTPUT.parent.mkdir(parents=True, exist_ok=True)
TEST_CROP_DIR.mkdir(parents=True, exist_ok=True)


def run(cmd):
    print('\n$', ' '.join(map(str, cmd)))
    result = subprocess.run(cmd, capture_output=True, text=True)
    if result.stdout:
        print(result.stdout)
    if result.stderr:
        print('[stderr]', result.stderr[:500])
    result.check_returncode()

# 1) Stage 1: test 원본 이미지 -> bbox predictions
run([
    sys.executable, 'scripts/predict.py',
    '--config', S1_CONFIG,
    '--weights', BEST_PT_S1,
    '--source', str(TEST_IMG_DIR),
    '--output', str(TEST_S1_PREDS),
])

# 2) Stage 1 bbox -> inference crop + manifest
run([
    sys.executable, 'scripts/pipeline/crop.py',
    '--predictions', str(TEST_S1_PREDS),
    '--source', str(TEST_IMG_DIR),
    '--output', str(TEST_CROP_DIR),
])

# 3) Stage 2: inference crop -> class predictions
run([
    sys.executable, 'scripts/pipeline/stage2_predict.py',
    '--config', S2_CONFIG,
    '--weights', BEST_PT_S2,
    '--source', str(TEST_CROP_DIR),
    '--output', str(TEST_S2_PREDS),
])

# 4) Submission: crop_id로 manifest와 Stage 2 prediction을 병합
cmd = [
    sys.executable, 'scripts/make_submission.py',
    '--manifest', str(TEST_MANIFEST),
    '--s2-preds', str(TEST_S2_PREDS),
    '--class-map', str(CLASS_MAP),
    '--output', str(SUBMISSION_OUTPUT),
]
if UNKNOWN_CLASS_MAP.exists():
    cmd += ['--unknown-class-map', str(UNKNOWN_CLASS_MAP)]
run(cmd)

manifest = json.loads(TEST_MANIFEST.read_text(encoding='utf-8'))
manifest_image_ids = {str(item['image_id']) for item in manifest}
manifest_crop_ids = {str(item['crop_id']) for item in manifest}
df_sub = pd.read_csv(SUBMISSION_OUTPUT)
submission_image_ids = set(df_sub['image_id'].astype(str))

unknown_image_ids = submission_image_ids - manifest_image_ids
leaked_crop_ids = submission_image_ids & (manifest_crop_ids - manifest_image_ids)
assert not unknown_image_ids, f'manifest 원본 image_id에 없는 제출 image_id: {sorted(unknown_image_ids)[:10]}'
assert not leaked_crop_ids, f'crop_id가 submission image_id로 유출됨: {sorted(leaked_crop_ids)[:10]}'

print(f'\n제출 파일: {SUBMISSION_OUTPUT}')
print(f'행 수: {len(df_sub):,}')
print(f'image_id 수: {len(submission_image_ids):,}')
display(df_sub.head())
# Out:
# 📦 Kaggle test 제출 파일 생성...
# ==================================================
#
# $ /home/n132/anaconda3/envs/P1/bin/python scripts/predict.py --config experiments/exp_20260503_efficientnet-b2/s1_config.yaml --weights experiments/exp_20260420_baseline_yolo26n/weights/best.pt --source data/test --output data/test/s1_predictions.json
#
# image 1/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/1.png: 640x512 4 pills, 103.2ms
# image 2/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/10.png: 640x512 4 pills, 12.7ms
# image 3/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/100.png: 640x512 4 pills, 34.5ms
# image 4/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/1003.png: 640x512 4 pills, 12.3ms
# image 5/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/1004.png: 640x512 4 pills, 12.6ms
# image 6/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/1005.png: 640x512 4 pills, 12.9ms
# image 7/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/
842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/286.png: 640x512 4 pills, 11.5ms
# image 396/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/287.png: 640x512 4 pills, 12.9ms
# image 397/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/288.png: 640x512 4 pills, 12.5ms
# image 398/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/289.png: 640x512 4 pills, 45.8ms
# image 399/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/29.png: 640x512 4 pills, 22.2ms
# image 400/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/291.png: 640x512 4 pills, 11.5ms
# image 401/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/292.png: 640x512 4 pills, 11.7ms
# image 402/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/295.png: 640x512 3 pills, 13.3ms
# image 403/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/298.png: 640x512 4 pills, 13.8ms
# image 404/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/299.png: 640x512 4 pills, 18.8ms
# image 405/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/3.png: 640x512 4 pills, 14.7ms
# image 406/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/302.png: 640x512 3 pills, 13.8ms
# image 407/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/304.png: 640x512 4 pills, 14.7ms
# image 408/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/308.png: 640x512 3 pills, 12.5ms
# image 409/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/31.png: 640x512 4 pills, 16.1ms
# image 410/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/310.png: 640x512 4 pills, 36.7ms
# image 411/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/313.png: 640x512 4 pills, 15.0ms
# image 412/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/315.png: 640x512 4 pills, 15.7ms
# image 413/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/316.png: 640x512 4 pills, 15.9ms
# image 414/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/317.png: 640x512 5 pills, 16.3ms
# image 415/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/32.png: 640x512 4 pills, 31.5ms
# image 416/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/320.png: 640x512 4 pills, 18.7ms
# image 417/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/323.png: 640x512 4 pills, 22.5ms
# image 418/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/324.png: 640x512 4 pills, 16.0ms
# image 419/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/325.png: 640x512 4 pills, 12.2ms
# image 420/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/327.png: 640x512 4 pills, 12.4ms
# ...
# image 721/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/798.png: 640x512 4 pills, 17.0ms
# image 722/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/799.png: 640x512 4 pills, 25.9ms
# image 723/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/8.png: 640x512 4 pills, 14.8ms
# image 724/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/80.png: 640x512 3 pills, 12.9ms
# image 725/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/807.png: 640x512 4 pills, 11.5ms
# image 726/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/808.png: 640x512 4 pills, 16.8ms
# image 727/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/810.png: 640x512 4 pills, 14.8ms
# image 728/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/815.png: 640x512 3 pills, 14.0ms
# image 729/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/817.png: 640x512 4 pills, 13.7ms
# image 730/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/818.png: 640x512 4 pills, 16.5ms
# image 731/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/819.png: 640x512 4 pills, 11.5ms
# image 732/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/82.png: 640x512 4 pills, 14.9ms
# image 733/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/820.png: 640x512 4 pills, 15.7ms
# image 734/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/822.png: 640x512 4 pills, 18.3ms
# image 735/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/826.png: 640x512 3 pills, 15.8ms
# image 736/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/828.png: 640x512 3 pills, 16.1ms
# image 737/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/829.png: 640x512 4 pills, 17.0ms
# image 738/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/83.png: 640x512 4 pills, 33.6ms
# image 739/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/830.png: 640x512 4 pills, 23.9ms
# image 740/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/831.png: 640x512 4 pills, 16.9ms
# image 741/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/832.png: 640x512 4 pills, 17.5ms
# image 742/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/838.png: 640x512 4 pills, 18.0ms
# image 743/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/842.png: 640x512 4 pills, 16.5ms
# image 744/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/85.png: 640x512 4 pills, 15.2ms
# image 745/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/851.png: 640x512 4 pills, 18.1ms
# image 746/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/855.png: 640x512 4 pills, 17.2ms
# image 747/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/857.png: 640x512 3 pills, 20.4ms
# image 748/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/858.png: 640x512 3 pills, 19.9ms
# image 749/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/86.png: 640x512 4 pills, 17.3ms
# image 750/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/861.png: 640x512 4 pills, 17.8ms
# image 751/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/862.png: 640x512 4 pills, 18.4ms
# image 752/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/864.png: 640x512 4 pills, 21.3ms
# image 753/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/866.png: 640x512 3 pills, 20.4ms
# image 754/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/867.png: 640x512 3 pills, 18.2ms
# image 755/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/868.png: 640x512 4 pills, 14.2ms
# image 756/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/869.png: 640x512 4 pills, 17.6ms
# image 757/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/870.png: 640x512 4 pills, 25.6ms
# image 758/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/873.png: 640x512 3 pills, 20.1ms
# image 759/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/874.png: 640x512 4 pills, 24.6ms
# image 760/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/875.png: 640x512 5 pills, 21.4ms
# image 761/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/878.png: 640x512 4 pills, 19.9ms
# image 762/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/879.png: 640x512 4 pills, 15.2ms
# image 763/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/88.png: 640x512 4 pills, 19.6ms
# image 764/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/880.png: 640x512 4 pills, 18.8ms
# image 765/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/882.png: 640x512 4 pills, 16.2ms
# image 766/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/883.png: 640x512 4 pills, 22.5ms
# image 767/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/886.png: 640x512 3 pills, 20.7ms
# image 768/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/888.png: 640x512 3 pills, 21.6ms
# image 769/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/889.png: 640x512 4 pills, 17.8ms
# image 770/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/89.png: 640x512 4 pills, 22.3ms
# image 771/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/891.png: 640x512 4 pills, 19.9ms
# image 772/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/894.png: 640x512 4 pills, 19.9ms
# image 773/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/895.png: 640x512 4 pills, 22.4ms
# image 774/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/896.png: 640x512 4 pills, 19.9ms
# image 775/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/897.png: 640x512 4 pills, 20.4ms
# image 776/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/898.png: 640x512 4 pills, 22.1ms
# image 777/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/9.png: 640x512 5 pills, 26.8ms
# image 778/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/90.png: 640x512 4 pills, 21.5ms
# image 779/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/900.png: 640x512 4 pills, 25.8ms
# image 780/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/904.png: 640x512 4 pills, 18.8ms
# image 781/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/906.png: 640x512 4 pills, 16.5ms
# image 782/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/908.png: 640x512 3 pills, 16.9ms
# image 783/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/91.png: 640x512 4 pills, 15.0ms
# image 784/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/910.png: 640x512 4 pills, 23.8ms
# image 785/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/912.png: 640x512 4 pills, 20.5ms
# image 786/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/914.png: 640x512 3 pills, 27.2ms
# image 787/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/915.png: 640x512 3 pills, 20.0ms
# image 788/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/916.png: 640x512 4 pills, 18.0ms
# image 789/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/919.png: 640x512 4 pills, 14.3ms
# image 790/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/920.png: 640x512 4 pills, 16.9ms
# image 791/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/923.png: 640x512 4 pills, 20.7ms
# image 792/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/925.png: 640x512 5 pills, 20.2ms
# image 793/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/927.png: 640x512 4 pills, 17.3ms
# image 794/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/929.png: 640x512 4 pills, 18.7ms
# image 795/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/930.png: 640x512 4 pills, 17.6ms
# image 796/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/931.png: 640x512 4 pills, 20.4ms
# image 797/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/932.png: 640x512 4 pills, 21.5ms
# image 798/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/933.png: 640x512 4 pills, 17.2ms
# image 799/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/936.png: 640x512 4 pills, 22.4ms
# image 800/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/937.png: 640x512 4 pills, 18.0ms
# image 801/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/938.png: 640x512 4 pills, 19.8ms
# image 802/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/940.png: 640x512 3 pills, 20.7ms
# image 803/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/941.png: 640x512 3 pills, 17.1ms
# image 804/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/942.png: 640x512 3 pills, 17.9ms
# image 805/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/945.png: 640x512 4 pills, 17.1ms
# image 806/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/947.png: 640x512 4 pills, 21.6ms
# image 807/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/948.png: 640x512 4 pills, 31.7ms
# image 808/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/949.png: 640x512 4 pills, 18.4ms
# image 809/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/95.png: 640x512 3 pills, 23.5ms
# image 810/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/950.png: 640x512 4 pills, 12.8ms
# image 811/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/951.png: 640x512 4 pills, 17.2ms
# image 812/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/952.png: 640x512 4 pills, 35.5ms
# image 813/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/953.png: 640x512 4 pills, 13.4ms
# image 814/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/954.png: 640x512 4 pills, 16.6ms
# image 815/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/956.png: 640x512 4 pills, 27.7ms
# image 816/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/957.png: 640x512 4 pills, 24.4ms
# image 817/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/962.png: 640x512 4 pills, 21.4ms
# image 818/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/966.png: 640x512 4 pills, 17.9ms
# image 819/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/967.png: 640x512 3 pills, 18.3ms
# image 820/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/968.png: 640x512 3 pills, 22.3ms
# image 821/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/97.png: 640x512 4 pills, 16.6ms
# image 822/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/972.png: 640x512 4 pills, 17.0ms
# image 823/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/973.png: 640x512 4 pills, 14.4ms
# image 824/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/974.png: 640x512 4 pills, 16.0ms
# image 825/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/975.png: 640x512 4 pills, 15.9ms
# image 826/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/979.png: 640x512 3 pills, 41.0ms
# image 827/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/980.png: 640x512 3 pills, 20.2ms
# image 828/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/982.png: 640x512 4 pills, 15.7ms
# image 829/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/983.png: 640x512 4 pills, 17.3ms
# image 830/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/984.png: 640x512 4 pills, 17.4ms
# image 831/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/985.png: 640x512 4 pills, 15.4ms
# image 832/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/986.png: 640x512 4 pills, 18.7ms
# image 833/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/988.png: 640x512 4 pills, 12.5ms
# image 834/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/989.png: 640x512 4 pills, 21.4ms
# image 835/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/990.png: 640x512 4 pills, 17.4ms
# image 836/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/991.png: 640x512 4 pills, 15.3ms
# image 837/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/993.png: 640x512 4 pills, 15.8ms
# image 838/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/994.png: 640x512 4 pills, 15.0ms
# image 839/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/996.png: 640x512 4 pills, 20.0ms
# image 840/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/997.png: 640x512 5 pills, 39.6ms
# image 841/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/998.png: 640x512 4 pills, 18.8ms
# image 842/842 /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/999.png: 640x512 4 pills, 19.9ms
# Speed: 1.7ms preprocess, 15.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 512)
# ⏱  s1_predict: 33.7초
# 완료: 842개 이미지 → /home/n132/Projects/Project1/codeit-part2-2team-project/data/test/s1_predictions.json
#
#
# $ /home/n132/anaconda3/envs/P1/bin/python scripts/pipeline/crop.py --predictions data/test/s1_predictions.json --source data/test --output data/test/s1_crops
# ⏱  crop: 16.6초
# 크롭 완료: 3252개 → data/test/s1_crops
#
#
# $ /home/n132/anaconda3/envs/P1/bin/python scripts/pipeline/stage2_predict.py --config experiments/exp_20260503_efficientnet-b2/s2_config.yaml --weights experiments/exp_20260503_efficientnet-b2/stage2/weights/best.pt --source data/test/s1_crops --output data/test/stage2_predictions.json
# ⏱  s2_predict: 4.6초
# 추론 완료: 3252개 → data/test/stage2_predictions.json
#
#
# $ /home/n132/anaconda3/envs/P1/bin/python scripts/make_submission.py --manifest data/test/s1_crops/crops_manifest.json --s2-preds data/test/stage2_predictions.json --class-map data/processed/kaggle_class_map.json --output submissions/exp_20260503_efficientnet-b2_submission2.csv --unknown-class-map data/processed/kaggle_unknown_class_map.json
# [submission] class_map 밖 8개 클래스 451개 detection을 fallback으로 치환: eswonamp_tab_20mg=35, gabapentin_tab_800mg_dong_a=118, januvia_tab_50mg=88, kanarb_tab_60mg=66, rabiet_tab20mg=35, stogar_tab_10mg=17, suspen_8_hours_er_tab=1, trajenta_tab=91
# [submission] class_map 밖 3개 클래스 4개 detection 제외: glyxambi_25_5mg_tab=1, isordil_10mg_tab=2, jardiance_duo_12_5_850mg_tab=1
# 제출 파일 생성 완료: submissions/exp_20260503_efficientnet-b2_submission2.csv
#
#
# 제출 파일: submissions/exp_20260503_efficientnet-b2_submission2.csv
# 행 수: 3,248
# image_id 수: 842
#    annotation_id  image_id  category_id  bbox_x  bbox_y  bbox_w  bbox_h  \
# 0              1         1        16551     558      73     396     403
# 1              2         1        36637     602     677     253     478
# 2              3         1        29345     174     742     178     290
# 3              4         1         1900     157     252     203     122
# 4              5        10        16548     103     809     240     238
#
#       score
# 0  0.872266
# 1  0.100299
# 2  0.164039
# 3  0.277723
# 4  0.579137

# %% [markdown]
# ---
#
# ## 💡 결과 해석 및 다음 단계
#
# ### 성능 지표 해석
#
# | 메트릭 | 의미 | 목표값 |
# |--------|------|--------|
# | **S1 Precision** | 탐지한 것 중 정답 비율 | > 0.95 |
# | **S1 Recall** | 정답 중 탐지한 비율 | > 0.95 |
# | **S1 mAP50** | 탐지 정확도 (관대함) | > 0.95 |
# | **S2 Top-1 Accuracy** | 분류 정확도 (1순위만 맞음) | > 0.80 |
# | **S2 Top-5 Accuracy** | 분류 정확도 (상위 5개 포함) | > 0.95 |
# | **S1 추론 시간** | Stage 1 추론 소요 시간 | < 60초 |
# | **Crop 생성 시간** | Crop 추출 소요 시간 | < 10초 |
# | **S2 추론 시간** | Stage 2 추론 소요 시간 | < 30초 |
# | **파이프라인 총 시간** | 전체 추론 파이프라인 | < 120초 |
#
# ### 개선 아이디어
#
# 1. **Stage 2 자동 튜닝**: Grid Search / Optuna로 `top1_acc` 기준 후보 탐색
# 2. **상위 trial E2E 검증**: best.pt 후보를 `evaluate_pipeline.py`로 Kaggle 기준 재평가
# 3. **데이터 증강 강화**: albumentations 설정에서 crop-level augmentation 조정
# 4. **모델 업그레이드**: `yolo26n` → `yolo26m`, Stage 2 backbone 변경
# 5. **임계값 조정**: 신뢰도 threshold를 조정해 precision/recall 트레이드오프 최적화
# 6. **하드 샘플 마이닝**: 자주 틀리는 이미지들을 수집해 재학습
#
# ### 다음 단계
#
# - ✅ 파이프라인 이해 완료
# - 📊 필요 시 Appendix의 Stage 2 자동 튜닝 / HPO로 후보 탐색
# - 🧪 상위 trial E2E 검증 후 best 후보 재학습
# - 🔧 Kaggle 제출 준비 ([제출 가이드](../scripts/README.md#kaggle-submission))
# - 📈 결과 분석 및 보고서 작성
#
# ---
#
# ### 📚 참고 자료
#
# - **스크립트**: `scripts/` 디렉토리
# - **설정**: `experiments/*/config.yaml`
# - **데이터**: `data/processed/dataset.yaml`
